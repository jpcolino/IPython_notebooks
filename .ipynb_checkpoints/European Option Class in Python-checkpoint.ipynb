# %% [markdown]
# ****
# # European Option Class for Risk-Neutral Pricing in Python
# ****
# ## About this notebook:
# Notebook prepared by **Jesus Perez Colino** Version 0.1, First Released: 21/03/2011, Alpha.
#
# - This work is licensed under a [Creative Commons Attribution-ShareAlike 3.0 Unported License](http://creativecommons.org/licenses/by-sa/3.0/deed.en_US). This work is offered for free, with the hope that it will be useful.
#
#
# - **Summary**: This notebook is just the simplest implementation of an abstract base class for the **European option** pricing and three different methods of pricing: **Black-Scholes, MonteCarlo and BinomialTree**. It also include the estimation of the sensitivities (**delta, gamma, vega, rho** and **theta**) in each of the three methodologies with **Unit-test suite**.
#
#
# - TODO: will be extended soon to FFT and PDEs
#
#
# - **Index**:
#        1. EuropeanOption: Abstract Base Class
#        2. Derived Classes:
#            2.1. BlackScholes Class
#            2.2. MonteCarlo Class
#            2.3. Binomial Class
#        3. Examples
#        4. 3D Plotting of Sensitivities
#        5. Unit-testing
#            5.1. Unittest for the Base Class
#            5.2. Unittest for BlackScholes Class
#            5.3. Unittest for Montecarlo Class
#            5.4. Unittest for Binomial Class
#
#
# - **Python & packages versions** to reproduce the results of this notebook:

# %%
import numpy as np
import IPython
from scipy.stats import norm
from abc import ABCMeta, abstractmethod
from sys import version 

print ' Reproducibility conditions for this notebook '.center(85,'-')
print 'Python version:     ' + version
print 'Numpy version:      ' + np.__version__
print 'IPython version:    ' + IPython.__version__
print '-'*85
# Out:
# -------------------- Reproducibility conditions for this notebook -------------------
# Python version:     2.7.10 |Anaconda 2.3.0 (x86_64)| (default, Sep 15 2015, 14:29:08)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# Numpy version:      1.9.2
# IPython version:    4.0.0
# -------------------------------------------------------------------------------------

# %% [markdown]
# ## 1. EuropeanOption: Abstract Base Class

# %%
class EuropeanOption(object):
    """ Abstract Class for European options. Partially implemented.
    S0 : float : initial stock/index level
    strike : float : strike price
    T : float : time to maturity (in year fractions)
    r : float : constant risk-free short rate
    div :    float : dividend yield
    sigma :  float : volatility factor in diffusion term
    model: str: name of the model for the pricing"""

    __metaclass__ = ABCMeta

    def __init__(self, option_type, S0, strike, T, r, div, sigma, model):
        try:
            self.option_type = option_type
            assert isinstance(option_type, str)
            self.S0 = float(S0)
            self.strike = float(strike)
            self.T = float(T)
            self.r = float(r)
            self.div = float(div)
            self.sigma = float(sigma)
            self.model = str(model)
        except ValueError:
            print('Error passing Options parameters')

        models = ['BlackScholes', 'MonteCarlo', 
                  'BinomialTree', 'TrinomialTree',
                  'FFT', 'PDE']
        
        if model not in models:
            raise Exception('Error: Model unknown')
            
        option_types = ['call', 'put']
        
        if option_type not in option_types:
            raise ValueError("Error: Option type not valid. Enter 'call' or 'put'")
        if S0 < 0 or strike < 0 or T <= 0 or r < 0 or div < 0 or sigma < 0:
            raise ValueError('Error: Negative inputs not allowed')
            
        self.discount = np.exp(-self.r * self.T)

    def getmodel(self):
        return self.model

    def __str__(self):
        return "This European Option is priced using {0}".format(self.getmodel())

    @abstractmethod
    def value(self):
        pass
        
    @abstractmethod
    def delta(self):
        pass

    @abstractmethod
    def gamma(self):
        pass

    @abstractmethod
    def vega(self):
        pass

    @abstractmethod
    def rho(self):
        pass
    
    @abstractmethod
    def theta(self):
        pass

# %% [markdown]
# ## 2. Derived Classses:
# ### 2.1. BlackScholes Class

# %%
class BlackScholes(EuropeanOption):

    def __init__(self, option_type, S0, strike, T, r, div, sigma):
        EuropeanOption.__init__(self,option_type, S0, strike, 
                                T, r, div, sigma, 'BlackScholes')
        
        d1 = ((np.log(self.S0 / self.strike) + 
              (self.r - self.div + 0.5 * (self.sigma ** 2)) * self.T) / 
              float( self.sigma * np.sqrt(self.T)))
        d2 = float(d1 - self.sigma * np.sqrt(self.T))
        self.Nd1 = norm.cdf(d1, 0, 1)
        self.Nnd1 = norm.cdf(-d1, 0, 1)
        self.Nd2 = norm.cdf(d2, 0, 1)
        self.Nnd2 = norm.cdf(-d2, 0, 1)
        self.pNd1 = norm.pdf(d1, 0, 1)
        
    @property
    def value(self):
        if self.option_type == 'call':
            value = (self.S0 * np.exp(-self.div * self.T) * self.Nd1 -
                     self.strike * np.exp(-self.r * self.T) * self.Nd2)
        else:
            value = (self.strike * np.exp(-self.r * self.T) * self.Nnd2 -
                     self.S0 * np.exp(-self.div * self.T) * self.Nnd1)
        return value
    
    @property
    def delta(self):
        if self.option_type == 'call':
            delta = np.exp(- self.div * self.T) * self.Nd1
        else:
            delta = np.exp(- self.div * self.T) * (self.Nd1 - 1)
        return delta
    
    @property
    def vega(self):
        vega = self.S0 * self.pNd1 * np.exp(- self.div * self.T) * np.sqrt(self.T)
        return vega
    
    @property
    def gamma(self):
        gamma = (self.pNd1 * np.exp(-self.div * self.T) / 
                 float(self.S0 * self.sigma * np.sqrt(self.T)))
        return gamma

    @property
    def rho(self):
        if self.option_type == 'call':
            rho = self.strike * self.T * np.exp(-self.r * self.T) * self.Nd2
        else:
            rho = - self.strike * self.T * np.exp(-self.r * self.T) * self.Nnd2
        return rho
    
    @property
    def theta(self):
        if self.option_type == 'call':
            theta = ((- self.S0 * self.pNd1 * self.sigma * np.exp(- self.div * self.T)) / 
                     float(2. * np.sqrt(self.T)) + 
                     self.div * self.S0 * self.Nd1 * np.exp(- self.div * self.T) - 
                     self.r * self.strike * np.exp(- self.r * self.T) * self.Nd2)
        else:
            theta = ((self.S0 * self.pNd1 * self.sigma * np.exp(- self.div * self.T)) /
                     float(2. * np.sqrt(self.T)) + 
                     self.div * self.S0 * self.Nnd1 * np.exp(- self.div * self.T) - 
                     self.r * self.strike * np.exp(- self.r * self.T) * self.Nnd2)
        return theta

# %% [markdown]
# ### 2.2. MonteCarlo Class

# %%
class MonteCarlo(EuropeanOption):

    def __init__(self, option_type, S0, strike, T, r, div, sigma, 
                 simulations = 500000, 
                 antithetic = True, 
                 moment_matching = True, 
                 fixed_seed = True):
        EuropeanOption.__init__(self, option_type, S0, strike, T, r, div, sigma, "MonteCarlo")
        self.simulations = int(simulations)
        self.antithetic = bool(antithetic)
        self.moment_matching = bool(moment_matching)
        self.fixed_seed = bool(fixed_seed)
        try:
            if self.simulations > 0 :
                assert isinstance(self.simulations, int)
        except:
            raise ValueError("Simulation's number has to be positive integer")
    
    def simulation_terminal(self, seed = 1234567890):
        if self.fixed_seed:
            assert isinstance(seed, int)
            np.random.seed(seed)
        if self.antithetic: 
            brownian = np.random.standard_normal(size = int(np.ceil(self.simulations/2.)))
            brownian = np.concatenate((brownian, -brownian))
        else:
            brownian = np.random.standard_normal(size = self.simulations)
        if self.moment_matching: 
            brownian = brownian - np.mean(brownian)
            brownian = brownian / np.std(brownian)
            
        price_terminal = self.S0 * np.exp((self.r - self.div - 0.5 * self.sigma ** 2) *
                                          self.T +
                                          self.sigma * np.sqrt(self.T) * brownian)
        return price_terminal

    def generate_payoffs(self):
        price_terminal = self.simulation_terminal()
        if self.option_type == 'call':
            payoff = np.maximum((price_terminal - self.strike), 0)
        else:
            payoff = np.maximum((self.strike - price_terminal), 0)
        return payoff

    @property
    def value(self):
        payoff = self.generate_payoffs()
        return self.discount * np.sum(payoff) / float(len(payoff))
    
    @property
    def delta_centered(self):
        diff = self.S0 * 0.01
        myCall_1 = MonteCarlo(self.option_type, self.S0 + diff, 
                              self.strike, self.T, self.r, self.div, self.sigma)
        myCall_2 = MonteCarlo(self.option_type, self.S0 - diff, 
                              self.strike, self.T, self.r, self.div, self.sigma)
        return (myCall_1.value - myCall_2.value) / float(2. * diff)
            
    @property
    def delta(self):
        value_terminal = np.array(self.simulation_terminal() / float(self.S0))
        payoff = self.generate_payoffs()
        delta = np.zeros(len(payoff))
        delta[np.nonzero(payoff)]= value_terminal[np.nonzero(payoff)]
        return self.discount * np.sum(delta) / float(len(payoff))

    @property
    def gamma(self): 
        diff = self.S0 * 0.01
        myCall_1 = MonteCarlo(self.option_type, self.S0 + diff,
                              self.strike, self.T, self.r, self.div, self.sigma)
        myCall_2 = MonteCarlo(self.option_type, self.S0 - diff,
                              self.strike, self.T, self.r, self.div, self.sigma)
        return (myCall_1.delta - myCall_2.delta) / float(2. * diff)

    @property
    def vega(self):
        diff = self.sigma * 0.01
        myCall_1 = MonteCarlo(self.option_type, self.S0,
                              self.strike, self.T, self.r, self.div, self.sigma + diff)
        myCall_2 = MonteCarlo(self.option_type, self.S0,
                              self.strike, self.T, self.r, self.div, self.sigma - diff)
        return (myCall_1.value - myCall_2.value) / float(2. * diff)

    @property
    def rho(self): 
        diff = self.r * 0.01
        if (self.r - diff) < 0:        
            myCall_1 = MonteCarlo(self.option_type, self.S0,
                                  self.strike, self.T, self.r + diff, self.div, self.sigma)
            myCall_2 = MonteCarlo(self.option_type, self.S0,
                                  self.strike, self.T, self.r, self.div, self.sigma)
            return (myCall_1.value - myCall_2.value) / float(diff)
        else:
            myCall_1 = MonteCarlo(self.option_type, self.S0 ,
                                  self.strike, self.T, self.r + diff, self.div, self.sigma)
            myCall_2 = MonteCarlo(self.option_type, self.S0,
                                  self.strike, self.T, self.r - diff, self.div, self.sigma)
            return (myCall_1.value - myCall_2.value) / float(2. * diff)
    
    @property
    def theta(self):         
        diff = 1 / 252.
        myCall_1 = MonteCarlo(self.option_type, self.S0,
                              self.strike, self.T + diff, self.r, self.div, self.sigma)
        myCall_2 = MonteCarlo(self.option_type, self.S0,
                              self.strike, self.T - diff, self.r, self.div, self.sigma)
        return (myCall_2.value - myCall_1.value) / float(2. * diff)

# %% [markdown]
# ### 2.3. BinomialTree Class

# %%
class BinomialTree(EuropeanOption):
    def __init__(self, option_type, S0, strike, T, r, div, sigma, time_grid ):
        EuropeanOption.__init__(self, option_type, S0, strike, 
                                T, r, div, sigma, "BinomialTree")
        self.time_grid = int(time_grid)
        if self.time_grid <= 0 :
            raise ValueError("Error: Number of time steps has to be positive integer")
    
    @property
    def value(self):
        delta_time = self.T / self.time_grid    
        discount = np.exp(-self.r * delta_time)
        move_up = np.exp(self.sigma * np.sqrt(delta_time))
        move_down = 1 / float(move_up)
        probability = ((np.exp(self.r * delta_time) - move_down) / 
                       float(move_up - move_down))
        index_up = np.arange(self.time_grid + 1)
        index_up = np.resize(index_up, (self.time_grid + 1, self.time_grid + 1))
        index_down = np.transpose(index_up)
        index_up = move_up ** (index_up - index_down)
        index_down = move_down ** index_down
        S = self.S0 * index_up * index_down
        if self.option_type == 'call':
            V = np.maximum(S - self.strike, 0)  
        else:
            V = np.maximum(self.strike - S, 0)   
        z=0
        for t in range(self.time_grid - 1, -1, -1): 
            V[0:self.time_grid - z, t] = (( probability * 
                                           V[0:self.time_grid - z, t + 1] + 
                                           (1 - probability) * 
                                           V[1:self.time_grid - z + 1, t + 1] ) *
                                          discount)
            z += 1
        return V[0,0]
    
    @property
    def delta(self):        
        diff = self.S0 * 0.01
        myCall_1 = BinomialTree(self.option_type, self.S0 + diff, 
                                self.strike, self.T, self.r, self.div, 
                                self.sigma, self.time_grid )
        myCall_2 = BinomialTree(self.option_type, self.S0 - diff, 
                                self.strike, self.T, self.r, self.div, 
                                self.sigma, self.time_grid )
        return (myCall_1.value - myCall_2.value) / float(2. * diff)

    @property
    def gamma(self):        
        diff = self.S0 * 0.01
        myCall_1 = BinomialTree(self.option_type, self.S0 + diff, 
                                self.strike, self.T, self.r, self.div, 
                                self.sigma, self.time_grid )
        myCall_2 = BinomialTree(self.option_type, self.S0 - diff, 
                                self.strike, self.T, self.r, self.div, 
                                self.sigma, self.time_grid )
        return (myCall_1.delta - myCall_2.delta) / float(2. * diff)

    @property
    def vega(self):
        diff = self.sigma * 0.01
        myCall_1 = BinomialTree(self.option_type, self.S0, self.strike, 
                                self.T, self.r, self.div, self.sigma + diff, 
                                self.time_grid )
        myCall_2 = BinomialTree(self.option_type, self.S0, self.strike, 
                                self.T, self.r, self.div, self.sigma - diff, 
                                self.time_grid )
        return (myCall_1.value - myCall_2.value) / float(2. * diff)

    @property
    def rho(self):        
        diff = self.r * 0.01
        if (self.r - diff) < 0:        
            myCall_1 = BinomialTree(self.option_type, self.S0,
                                    self.strike, self.T, self.r + diff, 
                                    self.div, self.sigma, self.time_grid )
            myCall_2 = BinomialTree(self.option_type, self.S0,
                                    self.strike, self.T, self.r, 
                                    self.div, self.sigma, self.time_grid )
            return (myCall_1.value - myCall_2.value) / float(diff)
        else:
            myCall_1 = BinomialTree(self.option_type, self.S0 ,
                                    self.strike, self.T, self.r + diff, 
                                    self.div, self.sigma, self.time_grid )
            myCall_2 = BinomialTree(self.option_type, self.S0,
                                    self.strike, self.T, self.r - diff, 
                                    self.div, self.sigma, self.time_grid )
            return (myCall_1.value - myCall_2.value) / float(2. * diff)
    
    @property
    def theta(self): 
        diff = 1 / 252.
        myCall_1 = BinomialTree(self.option_type, self.S0, self.strike, 
                                self.T + diff, self.r, self.div, self.sigma , 
                                self.time_grid )
        myCall_2 = BinomialTree(self.option_type, self.S0, self.strike, 
                                self.T - diff , self.r, self.div, self.sigma, 
                                self.time_grid )
        return (myCall_2.value - myCall_1.value) / float(2. * diff)

# %% [markdown]
# ## 3. Examples

# %%
myCall = BlackScholes('call', 100., 100., .5, 0.01, 0., .35)
print myCall
print 'Price: ', myCall.value
print 'Delta: ', myCall.delta
print 'Gamma: ', myCall.gamma
print 'Vega:  ', myCall.vega
print 'Rho:   ', myCall.rho
print 'Theta: ', myCall.theta
# Out:
# This European Option is priced using BlackScholes
# Price:  10.074989532
# Delta:  0.557228735645
# Gamma:  0.0159535590606
# Vega:   27.9187283561
# Rho:    22.8239420163
# Theta:  -10.2280337649

# %%
myCall = MonteCarlo('call', 100, 100, .5, 0.01, 0, 0.35)
print myCall
print 'Price: ', myCall.value
print 'Delta: ', myCall.delta
print 'Delta by diff: ', myCall.delta_centered
print 'Gamma: ', myCall.gamma
print 'Vega:  ', myCall.vega
print 'Rho:   ', myCall.rho
print 'Theta: ', myCall.theta
# Out:
# This European Option is priced using MonteCarlo
# Price:  10.0724838689
# Delta:  0.557266414517
# Delta by diff:  0.557156208448
# Gamma:  0.0160626128882
# Vega:   27.914136094
# Rho:    22.8276563804
# Theta:  -10.2265903743

# %%
myCall = BinomialTree('call', 100, 100, .5, 0.01, 0., 0.35, 252)
print myCall
print 'Price: ', myCall.value
print 'Delta: ', myCall.delta
print 'Gamma: ', myCall.gamma
print 'Vega:  ', myCall.vega
print 'Rho:   ', myCall.rho
print 'Theta: ', myCall.theta
# Out:
# This European Option is priced using BinomialTree
# Price:  10.0652469514
# Delta:  0.557172156732
# Gamma:  0.0247243132517
# Vega:   27.8910397013
# Rho:    22.8259843209
# Theta:  -10.2184642826

# %% [markdown]
# ## 4. 3D Plotting of Sensitivities

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
from matplotlib import rcParams

# %%
rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150

# %%
greeks = ['delta', 'gamma', 'vega', 'theta', 'rho']
maturities = np.linspace(0.01, 1, 150)
prices = np.linspace(80, 120, 150)
myfigure = plt.figure();
for num, greek in enumerate(greeks): 
    value = np.zeros((len(maturities), len(prices)), dtype=np.float)
    for i in range(len(prices)):
        for j in range(len(maturities)):
            myCall = BlackScholes('call', prices[i], 100., maturities[j], 0., 0., .35)
            value[j, i] = eval('myCall.{0}'.format(greek))

    x, y = np.meshgrid(prices, maturities)
    myfigure = plt.figure();
    plot = p3.Axes3D(myfigure)
    plot.plot_wireframe(x, y, value, alpha=0.2)
    plot.set_title('Graph {0}: {1} dynamics'.format(num, greek), 
                   fontdict=None, loc=u'center')
    plot.set_xlabel('Initial Price $S_0$ and Strike $100$')
    plot.set_ylabel('maturity $T$')
    plot.set_zlabel('{0} for $(S_0, T)$'.format(greek))

# %% [markdown]
# ## 5. Unit-testing
# ### 5.1. Unittest for the Base Class

# %%
import sys
import unittest

def concreter(abclass):
    if not "__abstractmethods__" in abclass.__dict__:
        return abclass
    new_dict = abclass.__dict__.copy()
    for abstractmethod in abclass.__abstractmethods__:
        new_dict[abstractmethod] = lambda x, *args, **kw: (x, args, kw)
    return type("dummy_concrete_%s" % abclass.__name__, (abclass,), new_dict)

EuropeanOption_test = concreter(EuropeanOption)


class EuropeanOptionTest(unittest.TestCase):
    
    def test_inputs(self):
        EuropeanOption_test_1 = EuropeanOption_test('call', 100, 101., 1, 0., 0., .35, 'BlackScholes')
        self.assertEqual(EuropeanOption_test_1.option_type, 'call')
        self.assertEqual(EuropeanOption_test_1.S0, 100)
        self.assertEqual(EuropeanOption_test_1.strike, 101)
        self.assertEqual(EuropeanOption_test_1.T, 1)
        self.assertEqual(EuropeanOption_test_1.r, 0.)
        self.assertEqual(EuropeanOption_test_1.div, 0.)
        self.assertEqual(EuropeanOption_test_1.sigma, .35)
        self.assertEqual(EuropeanOption_test_1.model, 'BlackScholes')
        
    def test_types_inputs(self):
        EuropeanOption_test_2 = EuropeanOption_test('put', 100, 101., 1, 0., 0., .35, 'MonteCarlo')
        self.assertTrue(type(EuropeanOption_test_1.option_type), str)
        self.assertTrue(type(EuropeanOption_test_1.S0), float)
        self.assertTrue(type(EuropeanOption_test_1.strike), float)
        self.assertTrue(type(EuropeanOption_test_1.T), float)
        self.assertTrue(type(EuropeanOption_test_1.r), float)
        self.assertTrue(type(EuropeanOption_test_1.div), float)
        self.assertTrue(type(EuropeanOption_test_1.sigma), float)
        self.assertTrue(type(EuropeanOption_test_1.model), str)
        
    def test_model_error(self):
        with self.assertRaises(Exception) as context: 
            EuropeanOption_test('put', 100., 101., 1, 0., 0., .35, 'MyMODEL')
        self.assertTrue('Error: Model unknown' in context.exception)

    def test_option_type_error(self):
        with self.assertRaises(Exception) as context: 
            EuropeanOption_test('Quanto', 100., 101., 1, 0., 0., .35, 'BlackScholes')
        self.assertTrue("Error: Option type not valid. Enter 'call' or 'put'" in context.exception)
        
    def test_option_negative_inputs_error(self):
        with self.assertRaises(Exception) as context: 
            EuropeanOption_test('call', -100., 101., 1, 0., 0., .35, 'BlackScholes')
        self.assertTrue('Error: Negative inputs not allowed' in context.exception)
        with self.assertRaises(Exception) as context: 
            EuropeanOption_test('call', 100., -101., 1, 0., 0., .35, 'BlackScholes')
        self.assertTrue('Error: Negative inputs not allowed' in context.exception)
        with self.assertRaises(Exception) as context: 
            EuropeanOption_test('call', 100., 101., -1, 0., 0., .35, 'BlackScholes')
        self.assertTrue('Error: Negative inputs not allowed' in context.exception)
        with self.assertRaises(Exception) as context: 
            EuropeanOption_test('call', 100., 101., 1, -0.12, 0., .35, 'BlackScholes')
        self.assertTrue('Error: Negative inputs not allowed' in context.exception)
        with self.assertRaises(Exception) as context: 
            EuropeanOption_test('call', 100., 101., 1, 0., -0.1, .35, 'BlackScholes')
        self.assertTrue('Error: Negative inputs not allowed' in context.exception)
        with self.assertRaises(Exception) as context: 
            EuropeanOption_test('call', 100., 101., 1, 0., 0., -.35, 'BlackScholes')
        self.assertTrue('Error: Negative inputs not allowed' in context.exception)

# %%
suite = unittest.TestLoader().loadTestsFromTestCase( EuropeanOptionTest )
unittest.TextTestRunner(verbosity=2,stream=sys.stderr).run( suite );
# Out:
# test_inputs (__main__.EuropeanOptionTest) ... ok
# test_model_error (__main__.EuropeanOptionTest) ... ok
# test_option_negative_inputs_error (__main__.EuropeanOptionTest) ... ok
# test_option_type_error (__main__.EuropeanOptionTest) ... ok
# test_types_inputs (__main__.EuropeanOptionTest) ... ok
#
# ----------------------------------------------------------------------
# Ran 5 tests in 0.002s
#
# OK

# %% [markdown]
# ### 5.2. Unitest for BlackScholes Class

# %%
class BlackScholesTest(unittest.TestCase):
    
    def test_value_OTM(self):
        BlackScholes_test_1 = BlackScholes('call', 0.0001, 100, 1, 0., 0., .35)
        self.assertAlmostEqual(BlackScholes_test_1.value, 0.)
        
    def test_value_ITM(self):
        BlackScholes_test_2 = BlackScholes('call', 100, 0.0001, 1, 0., 0., .35)
        self.assertAlmostEqual(round(BlackScholes_test_2.value, 3), 100)
        
    def test_value_high_vol(self):
        BlackScholes_test_3 = BlackScholes('call', 100, 100, 1, 0., 0., 99.)
        self.assertAlmostEqual(round(BlackScholes_test_3.value, 3), 100)
        
    def test_value_low_vol(self):
        BlackScholes_test_4 = BlackScholes('call', 100, 100, 1, 0., 0., .0000001)
        self.assertAlmostEqual(round(BlackScholes_test_4.value, 3), 0)
        
    def test_delta_OTM(self):
        BlackScholes_test_5 =BlackScholes('call', 0.0001, 100, 1, 0., 0., .35)
        self.assertAlmostEqual(BlackScholes_test_5.delta, 0.)
        
    def test_delta_ITM(self):
        BlackScholes_test_6 =BlackScholes('call', 100, .0001, 1, 0., 0., .35)
        self.assertAlmostEqual(BlackScholes_test_6.delta, 1.)
        
    def test_delta_high_vol(self):
        BlackScholes_test_7 =BlackScholes('call', 100, 100, 1, 0., 0., 99.)
        self.assertAlmostEqual(BlackScholes_test_7.delta, 1.)
        
    def test_delta_low_vol(self):
        BlackScholes_test_8 =BlackScholes('call', 100, 100, 1, 0., 0., .0000001)
        self.assertAlmostEqual(BlackScholes_test_8.delta, 0.5)

# %%
suite = unittest.TestLoader().loadTestsFromTestCase( BlackScholesTest )
unittest.TextTestRunner(verbosity=2,stream=sys.stderr).run( suite );
# Out:
# test_delta_ITM (__main__.BlackScholesTest) ... ok
# test_delta_OTM (__main__.BlackScholesTest) ... ok
# test_delta_high_vol (__main__.BlackScholesTest) ... ok
# test_delta_low_vol (__main__.BlackScholesTest) ... ok
# test_value_ITM (__main__.BlackScholesTest) ... ok
# test_value_OTM (__main__.BlackScholesTest) ... ok
# test_value_high_vol (__main__.BlackScholesTest) ... ok
# test_value_low_vol (__main__.BlackScholesTest) ... ok
#
# ----------------------------------------------------------------------
# Ran 8 tests in 0.009s
#
# OK

# %% [markdown]
# ### 5.3. Unittest for MonteCarlo Class

# %%
class MonteCarloTest(unittest.TestCase):
    
    def test_value_OTM(self):
        MonteCarlo_test_1 = MonteCarlo('call', 0.0001, 100, 1, 0., 0., .35)
        self.assertAlmostEqual(MonteCarlo_test_1.value, 0.)
        
    def test_value_ITM(self):
        MonteCarlo_test_2 = MonteCarlo('call', 100, 0.0001, 1, 0., 0., .35)
        self.assertAlmostEqual(round(MonteCarlo_test_2.value, 3), 100)
        
    def test_value_high_vol(self):
        MonteCarlo_test_3 = MonteCarlo('call', 100, 100, 1, 0., 0., 2.99)
        self.assertGreater(round(MonteCarlo_test_3.value, 3), 80)
        
    def test_value_low_vol(self):
        MonteCarlo_test_4 = MonteCarlo('call', 100, 100, 1, 0., 0., .0000001)
        self.assertAlmostEqual(round(MonteCarlo_test_4.value, 3), 0)
        
    def test_delta_OTM(self):
        MonteCarlo_test_5 = MonteCarlo('call', 0.0001, 100, 1, 0., 0., .35)
        self.assertAlmostEqual(MonteCarlo_test_5.delta, 0.)
        
    def test_delta_ITM(self):
        MonteCarlo_test_6 = MonteCarlo('call', 100, .0001, 1, 0., 0., .35)
        self.assertAlmostEqual(round(MonteCarlo_test_6.delta, 4), 1.)
        
    def test_delta_high_vol(self):
        MonteCarlo_test_7 = MonteCarlo('call', 100, 100, 1, 0., 0., 2.99)
        self.assertGreater(MonteCarlo_test_7.delta, .9)
        
    def test_delta_low_vol(self):
        MonteCarlo_test_8 = MonteCarlo('call', 100, 100, 1, 0., 0., .0000001)
        self.assertAlmostEqual(MonteCarlo_test_8.delta, 0.5)

# %%
suite = unittest.TestLoader().loadTestsFromTestCase( MonteCarloTest )
unittest.TextTestRunner(verbosity=2,stream=sys.stderr).run( suite );
# Out:
# test_delta_ITM (__main__.MonteCarloTest) ... ok
# test_delta_OTM (__main__.MonteCarloTest) ... ok
# test_delta_high_vol (__main__.MonteCarloTest) ... ok
# test_delta_low_vol (__main__.MonteCarloTest) ... ok
# test_value_ITM (__main__.MonteCarloTest) ... ok
# test_value_OTM (__main__.MonteCarloTest) ... ok
# test_value_high_vol (__main__.MonteCarloTest) ... ok
# test_value_low_vol (__main__.MonteCarloTest) ... ok
#
# ----------------------------------------------------------------------
# Ran 8 tests in 0.660s
#
# OK

# %% [markdown]
# ### 5.4. Unittest for BinomialTree Class

# %%
class BinomialTreeTest(unittest.TestCase):
    
    def test_value_OTM(self):
        BinomialTree_test_1 = BinomialTree('call', 0.0001, 100, 1, 0., 0., .35, 252)
        self.assertAlmostEqual(BinomialTree_test_1.value, 0.)
        
    def test_value_ITM(self):
        BinomialTree_test_2 = BinomialTree('call', 100, 0.0001, 1, 0., 0., .35, 252)
        self.assertAlmostEqual(round(BinomialTree_test_2.value, 3), 100)
        
    def test_value_high_vol(self):
        BinomialTree_test_3 = BinomialTree('call', 100, 100, 1, 0., 0., 2.99, 252)
        self.assertGreater(round(BinomialTree_test_3.value, 3), 80)
        
    def test_value_low_vol(self):
        BinomialTree_test_4 = BinomialTree('call', 100, 100, 1, 0., 0., .0000001, 252)
        self.assertAlmostEqual(round(BinomialTree_test_4.value, 3), 0)
        
    def test_delta_OTM(self):
        BinomialTree_test_5 = BinomialTree('call', 0.0001, 100, 1, 0., 0., .35, 252)
        self.assertAlmostEqual(BinomialTree_test_5.delta, 0.)
        
    def test_delta_ITM(self):
        BinomialTree_test_6 = BinomialTree('call', 100, .0001, 1, 0., 0., .35, 252)
        self.assertAlmostEqual(round(BinomialTree_test_6.delta, 4), 1.)
        
    def test_delta_high_vol(self):
        BinomialTree_test_7 = BinomialTree('call', 100, 100, 1, 0., 0., 2.99, 252)
        self.assertGreater(BinomialTree_test_7.delta, .9)
        
    def test_delta_low_vol(self):
        BinomialTree_test_8 = BinomialTree('call', 100, 100, 1, 0., 0., .0000001, 252)
        self.assertAlmostEqual(BinomialTree_test_8.delta, 0.5)

# %%
suite = unittest.TestLoader().loadTestsFromTestCase( BinomialTreeTest )
unittest.TextTestRunner(verbosity=2,stream=sys.stderr).run( suite );
# Out:
# test_delta_ITM (__main__.BinomialTreeTest) ... ok
# test_delta_OTM (__main__.BinomialTreeTest) ... ok
# test_delta_high_vol (__main__.BinomialTreeTest) ... ok
# test_delta_low_vol (__main__.BinomialTreeTest) ... ok
# test_value_ITM (__main__.BinomialTreeTest) ... ok
# test_value_OTM (__main__.BinomialTreeTest) ... ok
# test_value_high_vol (__main__.BinomialTreeTest) ... ok
# test_value_low_vol (__main__.BinomialTreeTest) ... ok
#
# ----------------------------------------------------------------------
# Ran 8 tests in 0.079s
#
# OK

# %%
EuropeanOption_test = concreter(EuropeanOption)
test_classes_to_run = [EuropeanOptionTest, BlackScholesTest, MonteCarloTest, BinomialTreeTest]
loader = unittest.TestLoader()
suites_list = []
for test_class in test_classes_to_run:
    suite = loader.loadTestsFromTestCase(test_class)
    suites_list.append(suite)

big_suite = unittest.TestSuite(suites_list)
runner = unittest.TextTestRunner(verbosity=2,stream=sys.stderr)
results = runner.run(big_suite)
# Out:
# test_inputs (__main__.EuropeanOptionTest) ... ok
# test_model_error (__main__.EuropeanOptionTest) ... ok
# test_option_negative_inputs_error (__main__.EuropeanOptionTest) ... ok
# test_option_type_error (__main__.EuropeanOptionTest) ... ok
# test_types_inputs (__main__.EuropeanOptionTest) ... ok
# test_delta_ITM (__main__.BlackScholesTest) ... ok
# test_delta_OTM (__main__.BlackScholesTest) ... ok
# test_delta_high_vol (__main__.BlackScholesTest) ... ok
# test_delta_low_vol (__main__.BlackScholesTest) ... ok
# test_value_ITM (__main__.BlackScholesTest) ... ok
# test_value_OTM (__main__.BlackScholesTest) ... ok
# test_value_high_vol (__main__.BlackScholesTest) ... ok
# test_value_low_vol (__main__.BlackScholesTest) ... ok
# test_delta_ITM (__main__.MonteCarloTest) ... ok
# test_delta_OTM (__main__.MonteCarloTest) ... ok
# test_delta_high_vol (__main__.MonteCarloTest) ... ok
# test_delta_low_vol (__main__.MonteCarloTest) ... ok
# test_value_ITM (__main__.MonteCarloTest) ... ok
# ...
