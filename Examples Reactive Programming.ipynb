# %% [markdown]
# # Examples of Reactive Programming for Machine Learning and Data Analysis

# %%
# %matplotlib inline
import os
import math
import IPython
import numexpr
import time as t
import numpy as np
import pandas as pd
from sys import version
import matplotlib.pyplot as plt
import matplotlib as mpl 
#os.chdir('C:\\Users\\Suso')
print '='*100
print 'Python version:     ' + version
print 'Numpy version:      ' + np.__version__
print 'Pandas version:     ' + pd.__version__
print 'Matplotlib ver:     ' + mpl.__version__
print 'IPython version:    ' + IPython.__version__
# numexpr.print_versions()
direct = %pwd
print 'Working directory:  ' + direct
print '='*100
now = t.asctime()
print 'Today is ' + now + ' ... AND WE ARE READY TO GO HOME!! '
print '='*100
# Out:
# ====================================================================================================
# Python version:     2.7.8 |Anaconda 2.0.0 (x86_64)| (default, Aug 21 2014, 15:21:46)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# Numpy version:      1.9.0
# Pandas version:     0.13.1
# Matplotlib ver:     1.4.0
# IPython version:    2.2.0
# Working directory:  /Users/JPC
# ====================================================================================================
# Today is Wed Sep 17 11:39:57 2014 ... AND WE ARE READY TO GO HOME!!
# ====================================================================================================

# %% [markdown]
# ## Introduction to the Reactive World

# %% [markdown]
# ### Example 1: The "Hello, World" in Reactive Programming

# %%
from peak.events import trellis

class TempConverter(trellis.Component):
     F = trellis.maintain(
         lambda self: self.C * 1.8 + 32,
         initially = 32
     )
     C = trellis.maintain(
         lambda self: (self.F - 32)/1.8,
         initially = 0
     )
     @trellis.perform
     def show_values(self):
         print "Celsius......", self.C
         print "Fahrenheit...", self.F


tc = TempConverter(C=100)
# Out:
# Celsius...... 100
# Fahrenheit... 212.0

# %%
tc.F = 32
# Out:
# Celsius...... 0.0
# Fahrenheit... 32

# %%
tc.C = 40
# Out:
# Celsius...... 40
# Fahrenheit... 104.0

# %%
tc.C = 40

# %% [markdown]
# ### Example 2: The "Hello Reactive World, again"

# %%
class Rectangle(trellis.Component):
    
    trellis.attrs(
        bottom = 0,
        width = 20,
        left = 0,
        height = 30
    )

    trellis.compute.attrs(
        top = lambda self: self.bottom + self.height,
        right  = lambda self: self.left + self.width,
    )

    @trellis.perform
    def show(self):
        print self

    def __repr__(self):
        return "Rectangle"+repr(
            ((self.left,self.bottom), 
             (self.width,self.height),
             (self.right,self.top))
        )

r1 = Rectangle()
# Out:
# Rectangle((0, 0), (20, 30), (20, 30))

# %%
r2 = Rectangle(width=40, height=10)
# Out:
# Rectangle((0, 0), (40, 10), (40, 10))

# %%
r2.width = 17
# Out:
# Rectangle((0, 0), (17, 10), (17, 10))

# %%
r2.left = 25
# Out:
# Rectangle((25, 0), (17, 10), (42, 10))

# %% [markdown]
# ### Example 3: Accessing a Rule's Previous Value

# %%
from peak.events import trellis
class NoiseFilter(trellis.Component):
    trellis.attrs( value = 0, threshhold = 5, )
    
    @trellis.maintain(initially =0)
    def filtered(self):
        if abs(self.value - self.filtered)> self.threshhold:
            return self.value
        return self.filtered

# %%
nf = NoiseFilter()
nf.filtered
# Out:
# 0

# %%
nf.value = 1
nf.filtered
# Out:
# 0

# %%
nf.value = 10
nf.filtered
# Out:
# 10

# %%
nf.value = 7
nf.filtered
# Out:
# 7

# %% [markdown]
# ## 1. Statistical Modelling in a Reactive Enviroment

# %% [markdown]
# ### Example 3 : Linear and Logistic Regressions

# %% [markdown]
# Let us start with a non-reactive simple regression.

# %%
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt

from sklearn import linear_model
clf = linear_model.LinearRegression()
data_x = [[0,0],[1,1],[2,2]]
data_y = [0,1,2]
clf.fit(data_x, data_y)

print "Coefficients : ", clf.coef_
print "Residual sum of squares: %.2f" % np.mean((clf.predict(data_x) - data_y)**2)
print data_x
len(data_x)
#plt.scatter(data_x, data_y, color = 'black')
# Out:
# Coefficients :  [ 0.5  0.5]
# Residual sum of squares: 0.00
# [[0, 0], [1, 1], [2, 2]]
# 3

# %%
whos
# Out:
# Variable             Type                Data/Info
# --------------------------------------------------
# LinearRegression     ABCMeta             <class 'sklearn.linear_mo<...>l.base.LinearRegression'>
# LogisticRegression   ABCMeta             <class 'sklearn.linear_mo<...>stic.LogisticRegression'>
# ReactRegression      classy_class        <class '__main__.ReactRegression'>
# Rectangle            classy_class        <class '__main__.Rectangle'>
# StandardScaler       type                <class 'sklearn.preproces<...>ing.data.StandardScaler'>
# X                    ndarray             1797x64: 115008 elems, type `float64`, 920064 bytes (898 kb)
# clf                  LinearRegression    LinearRegression(copy_X=T<...>pt=True, normalize=False)
# datasets             module              <module 'sklearn.datasets<...>n/datasets/__init__.pyc'>
# digits               Bunch               {'images': array([[[  0.,<...>[0, 1, 2, ..., 8, 9, 8])}
# linear_model         module              <module 'sklearn.linear_m<...>near_model/__init__.pyc'>
# linear_reg           LinearRegression    LinearRegression(copy_X=T<...>pt=True, normalize=False)
# np                   module              <module 'numpy' from '/Us<...>ages/numpy/__init__.pyc'>
# pl                   module              <module 'pylab' from '/Us<...>site-packages/pylab.pyc'>
# plt                  module              <module 'matplotlib.pyplo<...>s/matplotlib/pyplot.pyc'>
# r                    Rectangle           Rectangle((25, 0), (17, 10), (42, 10))
# r1                   Rectangle           Rectangle((0, 0), (20, 30), (20, 30))
# r2                   Rectangle           Rectangle((25, 0), (17, 10), (42, 10))
# show                 CellAttribute       CellAttribute('show')
# show_coef            CellAttribute       CellAttribute('show_coef')
# trellis              module              <module 'peak.events.trel<...>peak/events/trellis.pyc'>
# y                    ndarray             1797: 1797 elems, type `int64`, 14376 bytes

# %% [markdown]
# And let us move it to a reactive world

# %%
import pylab as pl
import numpy as np
from sklearn.linear_model import LinearRegression

linear_reg = linear_model.LinearRegression()
data_x = [[0,0],[1,1],[2,2],[3,2]]
data_y = [0,1,2,3]
linear_reg.fit(data_x,data_y)

print type(data_x)

coeff = linear_reg.fit(data_x, data_y)

print coeff.coef_[0]
print coeff.coef_[1]
# Out:
# <type 'list'>
# 1.0
# 1.66533453694e-16

# %%
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

from peak.events import trellis

linear_reg = linear_model.LinearRegression()
data_x = [[0,0],[1,1],[2,2]]
data_y = [0,1,2]
linear_reg.fit(data_x,data_y)
print type(data_x)

coeff = linear_reg.fit(data_x, data_y)

print "Coefficients : ", coeff.coef_

class ReactRegression(trellis.Component):
    
    trellis.attrs(
        x = len(data_x) ,
        y = len(data_y) ,
        a1 = coeff.coef_[0] ,
        a2 = coeff.coef_[1] ,
    )
    
    @trellis.maintain (initially = len(data_x))
    def reset_fit(self):
        if (self.x - self.reset_fit) > 0:
            reset_fit = 1 
            return reset_fit
        return self.reset_fit

            # coeff = linear_reg.fit(data_x, data_y)
           # a1 = coeff.coef_[0]
           # a2 = coeff.coef_[1]
            
    @trellis.perform
    def show_values(self):
        print "a1......", self.a1
        print "a2......", self.a2
        
coeff2 = ReactRegression()
print coeff2.x

print (coeff2.x - coeff2.reset_fit)
print coeff2.reset_fit
data_x = [[0,0],[1,1],[2,2],[3,2]]
data_y = [0,1,2,3]
coeff2 = ReactRegression()
# Out:
# <type 'list'>
# Coefficients :  [ 0.5  0.5]
# a1...... 0.5
# a2...... 0.5
# 3
# 0
# 3
# a1...... 0.5
# a2...... 0.5

# %%
whos
# Out:
# Variable             Type                Data/Info
# --------------------------------------------------
# IPython              module              <module 'IPython' from '/<...>es/IPython/__init__.pyc'>
# LinearRegression     ABCMeta             <class 'sklearn.linear_mo<...>l.base.LinearRegression'>
# LogisticRegression   ABCMeta             <class 'sklearn.linear_mo<...>stic.LogisticRegression'>
# NoiseFilter          classy_class        <class '__main__.NoiseFilter'>
# ReactRegression      classy_class        <class '__main__.ReactRegression'>
# Rectangle            classy_class        <class '__main__.Rectangle'>
# StandardScaler       type                <class 'sklearn.preproces<...>ing.data.StandardScaler'>
# TempConverter        classy_class        <class '__main__.TempConverter'>
# X                    ndarray             1797x64: 115008 elems, type `float64`, 920064 bytes (898 kb)
# clf                  LinearRegression    LinearRegression(copy_X=T<...>pt=True, normalize=False)
# coeff                LinearRegression    LinearRegression(copy_X=T<...>pt=True, normalize=False)
# data                 list                n=3
# data_x               list                n=3
# data_y               list                n=3
# datasets             module              <module 'sklearn.datasets<...>n/datasets/__init__.pyc'>
# digits               Bunch               {'images': array([[[  0.,<...>[0, 1, 2, ..., 8, 9, 8])}
# direct               unicode             /Users/JPC
# linear_model         module              <module 'sklearn.linear_m<...>near_model/__init__.pyc'>
# linear_reg           LinearRegression    LinearRegression(copy_X=T<...>pt=True, normalize=False)
# linear_reg2          LinearRegression    LinearRegression(copy_X=T<...>pt=True, normalize=False)
# math                 module              <module 'math' from '/Use<...>2.7/lib-dynload/math.so'>
# mpl                  module              <module 'matplotlib' from<...>matplotlib/__init__.pyc'>
# nf                   NoiseFilter         <__main__.NoiseFilter object at 0x10dcb2fd0>
# now                  str                 Wed Sep 17 11:39:57 2014
# np                   module              <module 'numpy' from '/Us<...>ages/numpy/__init__.pyc'>
# numexpr              module              <module 'numexpr' from '/<...>es/numexpr/__init__.pyc'>
# os                   module              <module 'os' from '/Users<...>da/lib/python2.7/os.pyc'>
# pd                   module              <module 'pandas' from '/U<...>ges/pandas/__init__.pyc'>
# pl                   module              <module 'pylab' from '/Us<...>site-packages/pylab.pyc'>
# plt                  module              <module 'matplotlib.pyplo<...>s/matplotlib/pyplot.pyc'>
# points               list                n=3
# points_y             list                n=3
# r                    Rectangle           Rectangle((25, 0), (17, 10), (42, 10))
# r1                   Rectangle           Rectangle((0, 0), (20, 30), (20, 30))
# r2                   Rectangle           Rectangle((25, 0), (17, 10), (42, 10))
# show                 CellAttribute       CellAttribute('show')
# show_coef            CellAttribute       CellAttribute('show_coef')
# t                    module              <module 'time' from '/Use<...>2.7/lib-dynload/time.so'>
# tc                   TempConverter       <__main__.TempConverter object at 0x10a2b9350>
# time                 module              <module 'time' from '/Use<...>2.7/lib-dynload/time.so'>
# trellis              module              <module 'peak.events.trel<...>peak/events/trellis.pyc'>
# version              str                 2.7.8 |Anaconda 2.0.0 (x8<...> (Apple Inc. build 5577)]
# y                    ndarray             1797: 1797 elems, type `int64`, 14376 bytes

# %%
a1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-200-763950971c8c> in <module>()
# ----> 1 a1
#
# NameError: name 'a1' is not defined

# %%
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
import time 
from sklearn.linear_model import LinearRegression

from peak.events import trellis

linear_reg2 = linear_model.LinearRegression()
data_x = [[0,0],[1,1],[2,2]]
data_y = [0,1,2]

type(data_x)
coeff = linear_reg2.fit(data_x, data_y)
print coeff

class ReactRegression(trellis.Component):
    coef_lreg = trellis.maintain(coeff)
    
@trellis.perform
def show(self):
    print self
    
def __repr__(self):
    return "Coefficients : " + repr(self.coef_)
    
    
reg1 = ReactRegression()
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-8baed72010ed> in <module>()
#      26
#      27
# ---> 28 reg1 = ReactRegression()
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/DecoratorTools-1.8-py2.7.egg/peak/util/decorators.pyc in __call__(cls, *args, **kw)
#     679
#     680     def __call__(cls, *args, **kw):
# --> 681         return cls.__class_call__.im_func(cls, *args, **kw)
#     682
#     683     if base is not type:
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in __class_call__(cls, *args, **kw)
#       3  def __class_call__(cls, *args, **kw):
#       4         if not __module.ctrl.active:
# ----> 5             return __module.atomically(__func, cls, *args, **kw)
#       6         elif __module.ctrl.current_listener is None:
#       7             return __func(cls, *args, **kw)
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in atomically(self, func, *args, **kw)
#     464         if self.active:
#     465             return func(*args, **kw)
# --> 466         return super(Controller,self).atomically(self._process, func, args, kw)
#     467
#     468     def _process(self, func, args, kw):
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in atomically(self, func, *args, **kw)
#     184                 return retval
#     185             except:
# --> 186                 self.cleanup(*sys.exc_info())
#     187         finally:
#     188             self.active = False
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in atomically(self, func, *args, **kw)
#     180         try:
#     181             try:
# --> 182                 retval = func(*args, **kw)
#     183                 self.cleanup()
#     184                 return retval
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in _process(self, func, args, kw)
#     468     def _process(self, func, args, kw):
#     469         try:
# --> 470             retval = func(*args, **kw)
#     471             layers = self.layers
#     472             queues = self.queues
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in __class_call__(cls, *args, **kw)
#     628                 if not v and k not in cells:
#     629                     c = cells.setdefault(k, CellFactories(cls)[k](cls, rv, k))
# --> 630                     c.value     # XXX
#     631         return rv
#     632
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in get_value(self)
#     519             if self._set_by is _sentinel:
#     520                 # No value set yet, so we have to run() first
# --> 521                 cancel(self); initialize(self)
#     522         if ctrl.current_listener is not None:
#     523             used(self)
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in initialize(self, listener)
#     518
#     519     def initialize(self, listener):
# --> 520         self.run_rule(listener, False)
#     521
#     522     def with_readonly(self, func, *args):
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in run_rule(self, listener, initialized)
#     358
#     359                 try:
# --> 360                     listener.run()
#     361                     self._process_writes(listener)
#     362                     self._process_reads(listener, initialized)
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in run(self)
#     543             # Nominal case: the value hasn't been set in this txn, or was only
#     544             # set by the rule itself.
# --> 545             super(Cell, self).run()
#     546         elif self._needs_init:
#     547             # Initialization case: value was set before reading, so we ignore
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in run(self)
#     192             change_attr(self, '_needs_init', False)
#     193             change_attr(self, '_set_by', self)
# --> 194             change_attr(self, '_value', self.rule())
#     195             on_commit(self._finish)
#     196         else:
#
# TypeError: 'LinearRegression' object is not callable

# %%
import time
# ?time.sleep

# %%
reg1 = ReactRegression()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-ebeacedb5e3a> in <module>()
# ----> 1 reg1 = ReactRegression()
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/DecoratorTools-1.8-py2.7.egg/peak/util/decorators.pyc in __call__(cls, *args, **kw)
#     679
#     680     def __call__(cls, *args, **kw):
# --> 681         return cls.__class_call__.im_func(cls, *args, **kw)
#     682
#     683     if base is not type:
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in __class_call__(cls, *args, **kw)
#       3  def __class_call__(cls, *args, **kw):
#       4         if not __module.ctrl.active:
# ----> 5             return __module.atomically(__func, cls, *args, **kw)
#       6         elif __module.ctrl.current_listener is None:
#       7             return __func(cls, *args, **kw)
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in atomically(self, func, *args, **kw)
#     464         if self.active:
#     465             return func(*args, **kw)
# --> 466         return super(Controller,self).atomically(self._process, func, args, kw)
#     467
#     468     def _process(self, func, args, kw):
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in atomically(self, func, *args, **kw)
#     184                 return retval
#     185             except:
# --> 186                 self.cleanup(*sys.exc_info())
#     187         finally:
#     188             self.active = False
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in atomically(self, func, *args, **kw)
#     180         try:
#     181             try:
# --> 182                 retval = func(*args, **kw)
#     183                 self.cleanup()
#     184                 return retval
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in _process(self, func, args, kw)
#     468     def _process(self, func, args, kw):
#     469         try:
# --> 470             retval = func(*args, **kw)
#     471             layers = self.layers
#     472             queues = self.queues
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in __class_call__(cls, *args, **kw)
#     628                 if not v and k not in cells:
#     629                     c = cells.setdefault(k, CellFactories(cls)[k](cls, rv, k))
# --> 630                     c.value     # XXX
#     631         return rv
#     632
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in get_value(self)
#     519             if self._set_by is _sentinel:
#     520                 # No value set yet, so we have to run() first
# --> 521                 cancel(self); initialize(self)
#     522         if ctrl.current_listener is not None:
#     523             used(self)
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in initialize(self, listener)
#     518
#     519     def initialize(self, listener):
# --> 520         self.run_rule(listener, False)
#     521
#     522     def with_readonly(self, func, *args):
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in run_rule(self, listener, initialized)
#     358
#     359                 try:
# --> 360                     listener.run()
#     361                     self._process_writes(listener)
#     362                     self._process_reads(listener, initialized)
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in run(self)
#     543             # Nominal case: the value hasn't been set in this txn, or was only
#     544             # set by the rule itself.
# --> 545             super(Cell, self).run()
#     546         elif self._needs_init:
#     547             # Initialization case: value was set before reading, so we ignore
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in run(self)
#     192             change_attr(self, '_needs_init', False)
#     193             change_attr(self, '_set_by', self)
# --> 194             change_attr(self, '_value', self.rule())
#     195             on_commit(self._finish)
#     196         else:
#
# TypeError: 'LinearRegression' object is not callable

# %%
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

from peak.events import trellis

linear_reg = linear_model.LinearRegression()

print linear_reg

class ReactRegression(trellis.Component):
    coef_lreg = trellis.maintain(
        linear_reg.fit([[0,0],[1,1],[2,2]],[0,1,2])
    )
    
@trellis.perform
def show_coef(self):
    print "Coefficients : " + self.coef_
            
Reg1 = ReactRegression()
#[[0,0],[1,1],[2,2]],[0,1,2]
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-a952bc05f241> in <module>()
#      20     print "Coefficients : " + self.coef_
#      21
# ---> 22 Reg1 = ReactRegression()
#      23 #[[0,0],[1,1],[2,2]],[0,1,2]
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/DecoratorTools-1.8-py2.7.egg/peak/util/decorators.pyc in __call__(cls, *args, **kw)
#     679
#     680     def __call__(cls, *args, **kw):
# --> 681         return cls.__class_call__.im_func(cls, *args, **kw)
#     682
#     683     if base is not type:
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in __class_call__(cls, *args, **kw)
#       3  def __class_call__(cls, *args, **kw):
#       4         if not __module.ctrl.active:
# ----> 5             return __module.atomically(__func, cls, *args, **kw)
#       6         elif __module.ctrl.current_listener is None:
#       7             return __func(cls, *args, **kw)
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in atomically(self, func, *args, **kw)
#     464         if self.active:
#     465             return func(*args, **kw)
# --> 466         return super(Controller,self).atomically(self._process, func, args, kw)
#     467
#     468     def _process(self, func, args, kw):
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in atomically(self, func, *args, **kw)
#     184                 return retval
#     185             except:
# --> 186                 self.cleanup(*sys.exc_info())
#     187         finally:
#     188             self.active = False
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in atomically(self, func, *args, **kw)
#     180         try:
#     181             try:
# --> 182                 retval = func(*args, **kw)
#     183                 self.cleanup()
#     184                 return retval
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in _process(self, func, args, kw)
#     468     def _process(self, func, args, kw):
#     469         try:
# --> 470             retval = func(*args, **kw)
#     471             layers = self.layers
#     472             queues = self.queues
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in __class_call__(cls, *args, **kw)
#     628                 if not v and k not in cells:
#     629                     c = cells.setdefault(k, CellFactories(cls)[k](cls, rv, k))
# --> 630                     c.value     # XXX
#     631         return rv
#     632
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in get_value(self)
#     519             if self._set_by is _sentinel:
#     520                 # No value set yet, so we have to run() first
# --> 521                 cancel(self); initialize(self)
#     522         if ctrl.current_listener is not None:
#     523             used(self)
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in initialize(self, listener)
#     518
#     519     def initialize(self, listener):
# --> 520         self.run_rule(listener, False)
#     521
#     522     def with_readonly(self, func, *args):
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/stm.pyc in run_rule(self, listener, initialized)
#     358
#     359                 try:
# --> 360                     listener.run()
#     361                     self._process_writes(listener)
#     362                     self._process_reads(listener, initialized)
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in run(self)
#     543             # Nominal case: the value hasn't been set in this txn, or was only
#     544             # set by the rule itself.
# --> 545             super(Cell, self).run()
#     546         elif self._needs_init:
#     547             # Initialization case: value was set before reading, so we ignore
#
# /Users/JPC/anaconda/lib/python2.7/site-packages/Trellis-0.7a2-py2.7.egg/peak/events/trellis.pyc in run(self)
#     192             change_attr(self, '_needs_init', False)
#     193             change_attr(self, '_set_by', self)
# --> 194             change_attr(self, '_value', self.rule())
#     195             on_commit(self._finish)
#     196         else:
#
# TypeError: 'LinearRegression' object is not callable

# %%
whos
# Out:
# Variable             Type                Data/Info
# --------------------------------------------------
# LogisticRegression   ABCMeta             <class 'sklearn.linear_mo<...>stic.LogisticRegression'>
# ReactRegression      classy_class        <class '__main__.ReactRegression'>
# StandardScaler       type                <class 'sklearn.preproces<...>ing.data.StandardScaler'>
# X                    ndarray             1797x64: 115008 elems, type `float64`, 920064 bytes (898 kb)
# clf                  LinearRegression    LinearRegression(copy_X=T<...>pt=True, normalize=False)
# datasets             module              <module 'sklearn.datasets<...>n/datasets/__init__.pyc'>
# digits               Bunch               {'images': array([[[  0.,<...>[0, 1, 2, ..., 8, 9, 8])}
# linear_model         module              <module 'sklearn.linear_m<...>near_model/__init__.pyc'>
# linear_reg           LinearRegression    LinearRegression(copy_X=T<...>pt=True, normalize=False)
# np                   module              <module 'numpy' from '/Us<...>ages/numpy/__init__.pyc'>
# pl                   module              <module 'pylab' from '/Us<...>site-packages/pylab.pyc'>
# plt                  module              <module 'matplotlib.pyplo<...>s/matplotlib/pyplot.pyc'>
# show_coef            CellAttribute       CellAttribute('show_coef')
# trellis              module              <module 'peak.events.trel<...>peak/events/trellis.pyc'>
# y                    ndarray             1797: 1797 elems, type `int64`, 14376 bytes

# %%
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn.preprocessing import StandardScaler

digits = datasets.load_digits()

X, y = digits.data, digits.target

print X.shape

print y.shape

print y.size
# Out:
# (1797, 64)
# (1797,)
# 1797

# %%
# ?datasets.load_digits

# %%
# %pylab inline
import numpy as np
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn.preprocessing import StandardScaler

digits = datasets.load_digits()

X, y = digits.data, digits.target
X = StandardScaler().fit_transform(X)

# classify small against large digits
y = (y > 4).astype(np.int)


# Set regularization parameter
for i, C in enumerate(10. ** np.arange(1, 4)):
    # turn down tolerance for short training time
    clf_l1_LR = LogisticRegression(C=C, penalty='l1', tol=0.01)
    clf_l2_LR = LogisticRegression(C=C, penalty='l2', tol=0.01)
    clf_l1_LR.fit(X, y)
    clf_l2_LR.fit(X, y)

    coef_l1_LR = clf_l1_LR.coef_.ravel()
    coef_l2_LR = clf_l2_LR.coef_.ravel()

    # coef_l1_LR contains zeros due to the
    # L1 sparsity inducing norm

    sparsity_l1_LR = np.mean(coef_l1_LR == 0) * 100
    sparsity_l2_LR = np.mean(coef_l2_LR == 0) * 100

    print("C=%d" % C)
    print("Sparsity with L1 penalty: %.2f%%" % sparsity_l1_LR)
    print("score with L1 penalty: %.4f" % clf_l1_LR.score(X, y))
    print("Sparsity with L2 penalty: %.2f%%" % sparsity_l2_LR)
    print("score with L2 penalty: %.4f" % clf_l2_LR.score(X, y))

    l1_plot = plt.subplot(3, 2, 2 * i + 1)
    l2_plot = plt.subplot(3, 2, 2 * (i + 1))
    if i == 0:
        l1_plot.set_title("L1 penalty")
        l2_plot.set_title("L2 penalty")

    l1_plot.imshow(np.abs(coef_l1_LR.reshape(8, 8)), interpolation='nearest',
                   cmap='binary', vmax=1, vmin=0)
    l2_plot.imshow(np.abs(coef_l2_LR.reshape(8, 8)), interpolation='nearest',
                   cmap='binary', vmax=1, vmin=0)
    plt.text(-8, 3, "C = %d" % C)

    l1_plot.set_xticks(())
    l1_plot.set_yticks(())
    l2_plot.set_xticks(())
    l2_plot.set_yticks(())

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C=10
# Sparsity with L1 penalty: 6.25%
# score with L1 penalty: 0.9093
# Sparsity with L2 penalty: 4.69%
# score with L2 penalty: 0.9093
# C=100
# Sparsity with L1 penalty: 4.69%
# score with L1 penalty: 0.9104
# Sparsity with L2 penalty: 4.69%
# score with L2 penalty: 0.9098
# C=1000
# Sparsity with L1 penalty: 4.69%
# score with L1 penalty: 0.9098
# Sparsity with L2 penalty: 4.69%
# score with L2 penalty: 0.9098

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.lda import LDA
from sklearn.qda import QDA

from peak.events import trellis

m = 1000  # number of simulations
h = .02   # step size in the mesh

names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Decision Tree",
         "Random Forest", "AdaBoost", "Naive Bayes", "LDA", "QDA"]
classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    AdaBoostClassifier(),
    GaussianNB(),
    LDA(),
    QDA()]

X, y = make_classification(n_samples=m, n_features=2, n_redundant=0, n_informative=2,
                           random_state=1, n_clusters_per_class=1)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)
linearly_separable = (X, y)

datasets = [make_moons(noise=0.3, random_state=0),
            make_circles(noise=0.2, factor=0.5, random_state=1),
            linearly_separable
            ]

figure = plt.figure(figsize=(27, 9))
i = 1
# iterate over datasets
for ds in datasets:
    # preprocess dataset, split into training and test part
    X, y = ds
    X = StandardScaler().fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4)

    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    # just plot the dataset first
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])
    ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
    # Plot the training points
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright)
    # and testing points
    ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6)
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xticks(())
    ax.set_yticks(())
    i += 1

    # iterate over classifiers
    for name, clf in zip(names, classifiers):
        ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
        clf.fit(X_train, y_train)
        score = clf.score(X_test, y_test)

        # Plot the decision boundary. For that, we will assign a color to each
        # point in the mesh [x_min, m_max]x[y_min, y_max].
        if hasattr(clf, "decision_function"):
            Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
        else:
            Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        ax.contourf(xx, yy, Z, cmap=cm, alpha=.8)

        # Plot also the training points
        ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright)
        # and testing points
        ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright,
                   alpha=0.6)

        ax.set_xlim(xx.min(), xx.max())
        ax.set_ylim(yy.min(), yy.max())
        ax.set_xticks(())
        ax.set_yticks(())
        ax.set_title(name)
        ax.text(xx.max() - .3, yy.min() + .3, ('%.2f' % score).lstrip('0'),
                size=15, horizontalalignment='right')
        i += 1

figure.subplots_adjust(left=.02, right=.98)
plt.show()

# %%
# ?make_classification

# %%
whos
# Out:
# Variable                 Type                       Data/Info
# -------------------------------------------------------------
# AdaBoostClassifier       ABCMeta                    <class 'sklearn.ensemble.<...>ting.AdaBoostClassifier'>
# DecisionTreeClassifier   ABCMeta                    <class 'sklearn.tree.tree<...>.DecisionTreeClassifier'>
# GaussianNB               ABCMeta                    <class 'sklearn.naive_bayes.GaussianNB'>
# KNeighborsClassifier     ABCMeta                    <class 'sklearn.neighbors<...>on.KNeighborsClassifier'>
# LDA                      type                       <class 'sklearn.lda.LDA'>
# ListedColormap           type                       <class 'matplotlib.colors.ListedColormap'>
# QDA                      type                       <class 'sklearn.qda.QDA'>
# RandomForestClassifier   ABCMeta                    <class 'sklearn.ensemble.<...>.RandomForestClassifier'>
# SVC                      ABCMeta                    <class 'sklearn.svm.classes.SVC'>
# StandardScaler           type                       <class 'sklearn.preproces<...>ing.data.StandardScaler'>
# X                        ndarray                    1000x2: 2000 elems, type `float64`, 16000 bytes
# X_test                   ndarray                    400x2: 800 elems, type `float64`, 6400 bytes
# X_train                  ndarray                    600x2: 1200 elems, type `float64`, 9600 bytes
# Z                        ndarray                    327x407: 133089 elems, type `float64`, 1064712 bytes (1 Mb)
# ax                       AxesSubplot                Axes(0.898644,0.125;0.0813559x0.227941)
# classifiers              list                       n=9
# clf                      QDA                        QDA(priors=None, reg_param=0.0)
# cm                       LinearSegmentedColormap    <matplotlib.colors.Linear<...>ap object at 0x10792cc50>
# cm_bright                ListedColormap             <matplotlib.colors.Listed<...>ap object at 0x10a97c050>
# datasets                 list                       n=3
# ds                       tuple                      n=2
# figure                   Figure                     Figure(2160x720)
# h                        float                      0.02
# i                        int                        31
# linearly_separable       tuple                      n=2
# m                        int                        1000
# make_circles             function                   <function make_circles at 0x109e5bed8>
# make_classification      function                   <function make_classification at 0x109e5bcf8>
# make_moons               function                   <function make_moons at 0x109e5bf50>
# name                     str                        QDA
# names                    list                       n=9
# np                       module                     <module 'numpy' from '/Us<...>ages/numpy/__init__.pyc'>
# plt                      module                     <module 'matplotlib.pyplo<...>s/matplotlib/pyplot.pyc'>
# rng                      RandomState                <mtrand.RandomState object at 0x10d90bd50>
# score                    float64                    0.8675
# train_test_split         function                   <function train_test_split at 0x109d5b1b8>
# trellis                  module                     <module 'peak.events.trel<...>peak/events/trellis.pyc'>
# x_max                    float64                    4.13418664439
# x_min                    float64                    -3.99550206713
# xx                       ndarray                    327x407: 133089 elems, type `float64`, 1064712 bytes (1 Mb)
# y                        ndarray                    1000: 1000 elems, type `int64`, 8000 bytes
# y_max                    float64                    3.01854706831
# y_min                    float64                    -3.51610691008
# y_test                   ndarray                    400: 400 elems, type `int64`, 3200 bytes
# y_train                  ndarray                    600: 600 elems, type `int64`, 4800 bytes
# yy                       ndarray                    327x407: 133089 elems, type `float64`, 1064712 bytes (1 Mb)

# %%
X, y = make_classification(n_samples=m, n_features=2, n_redundant=0, n_informative=2,
                           random_state=1, n_clusters_per_class=1)

# %%
y.size
# Out:
# 1000

# %%
len(datasets)
# Out:
# 3
