# %% [markdown]
# ****
# # WebScrapping Internet with Python
# ****
# <p style="text-align: right"><i>Jesus Perez Colino<br>First version: Oct 2014<br>Last revision: Nov 2015</i></p>

# %% [markdown]
# ### About this notebook:
# Notebook prepared by **Jesus Perez Colino** Version 0.1, First Released: 01/10/2014, Alpha.
#
# - This work is licensed under a [Creative Commons Attribution-ShareAlike 3.0 Unported License](http://creativecommons.org/licenses/by-sa/3.0/deed.en_US). This work is offered for free, with the hope that it will be useful.
#
#
# - **Summary**: This notebook contains a brief introduction about how to work with **Excel Spreadsheets** from Python using **openpyxl** and **pandas**.
#
#
# - **Python & packages versions** to reproduce the results of this notebook:

# %%
import IPython
import re
from sys import version 
from urllib import urlopen
from bs4 import BeautifulSoup 
print ' Reproducibility conditions for this notebook '.center(85,'-')
print 'Python version:     ' + version
print 'RegEx version:      ' + re.__version__
print 'IPython version:    ' + IPython.__version__
print '-'*85
# Out:
# -------------------- Reproducibility conditions for this notebook -------------------
# Python version:     2.7.10 |Anaconda 2.4.0 (x86_64)| (default, Oct 19 2015, 18:31:17)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# RegEx version:      2.2.1
# IPython version:    4.0.0
# -------------------------------------------------------------------------------------

# %% [markdown]
# # Introduction

# %% [markdown]
# Before to begin to design web-scrapping functions, there are two basic concepts that we need to review in order to be able to build efficient web-scrappy functions:
# - *first*, Regular Expressions and
# - *second*, the package BeautifulSoup.
#
# ## Basics about Regular Expressions (regex)
#
# In the context of this notebook, a **Regular Expression** is a specific kind of text pattern that you can use with many modern applications, and not only in Python but also with many programming languages (like Java, Scala, Perl or Ruby). You can use them to verify whether input fits into the text pattern, to find text that matches the pattern within a larger body of text, to replace text matching the pattern with other text or rearranged bits of the matched text, to split a block of text into a list of subtexts, and to shoot yourself in the foot.
#
# **Regular expressions** are so called because they are used to identify *regular strings* defined as any string that can be generated by a series of linear rules. For instance:
# - Write the letter “a” at least once.
# - Append to this the letter “b” exactly five times.
# - Append to this the letter “c” any even number of times.
# - Optionally, write the letter “d” at the end.
#
# Notice that strings that follow these rules are: `aaaabbbbbccccd`, `aabbbbbcc`, and so on (there are an infinite number of variations).
#
# Regular expressions are merely a shorthand way of expressing these sets of rules. For instance, here’s the regular expression for the series of steps just described:
#
# `aa*bbbbb(cc)*(d | )`
#
#
# where
#
# - `aa*` The letter `a` is written, followed by `a*` (read as a star) which means “any number of a’s, including 0 of them.”
# - `bbbbb` five b’s in a row
# - `(cc)*` two c’s, surround them in parentheses, and write an asterisk after it, meaning that you can have any number of pairs of c’s (note that this can mean 0 pairs, as well)
# - `(d|)` Adding a bar in the middle of two expressions means that it can be “this thing or that thing.” In this case, we are saying “add a d followed by a space or just add a space without a d.”
#
# The most classical example of regular expression is a regex that will automatically idetify an email address:
#
# `[A-Za-z0-9\._+-]+@[A-Za-z]+\.(com|org|edu|net)`
#
# - `[A-Za-z0-9\._+-]+` helps to collect any email address that contains at least one of the following features: uppercase letters, lowercase letters, the numbers 0-9, periods (.), plus signs (+) or (-), or underscores (_). “A-Z” means “any uppercase letter, A through Z.” By putting all these possible sequences and symbols in brackets (as opposed to parentheses) we are saying “this symbol can be any one of these things we’ve listed in the brackets.” Note also that the final + sign means “these characters can occur as many times as they want to, but must occur at least once.”
# - `@` the email address should contains the @ symbol
# - `[A-Za-z]+` means that the email address then must contain at least one uppercase or lowercase letter.
# - `\.` followed by a period (.)
# - `(com|org|edu|net)` ended with *com, org, edu, or net* (in reality, there are many possible top-level domains, but, these four should suffice for the sake of example)

# %%
import re
p = re.compile("[A-Za-z0-9\._+-]+@[A-Za-z]+\.(com|org|edu|net)")
print p
# Out:
# <_sre.SRE_Pattern object at 0x105c2d6d0>

# %%
string = 'purple alice-b@mymail.com monkey dishwasher'
match = re.search(p, string)
if match:
    print match.group()
# Out:
# alice-b@mymail.com

# %% [markdown]
# ## Basics about Beautiful Soup
#
# Beautiful Soup is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree.
#
# Here’s an HTML document as a basic example (taken from [Beautiful documentation](http://www.crummy.com/software/BeautifulSoup/bs4/doc/)) for this introduction:

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
print soup.title
print soup.title.name
print soup.title.string
# Out:
# <title>The Dormouse's story</title>
# title
# The Dormouse's story

# %%
print soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
# One common task is extracting all the URLs found within a page’s <a> tags:

for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
# Another common task is extracting all the text from a page:

print(soup.get_text())
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
print(soup.prettify(formatter="minimal"))
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# # Some Crawling Examples
#
# **Example 1**: Create a list of the content related with the Black-Scholes model that is currently in Wikipedia.
#
# If you run this, you should see a list of all article URLs that the Wikipedia article on Black-Scholes model links to.

# %%
from urllib import urlopen
from bs4 import BeautifulSoup 
import re

html = urlopen("https://en.wikipedia.org/wiki/Black–Scholes_model")
bsObj = BeautifulSoup(html)
for link in bsObj.find("div", {"id":"bodyContent"}).findAll("a", 
                        href=re.compile("^(/wiki/)((?!:).)*$")):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Mathematical_model
# /wiki/Financial_market
# /wiki/Derivative_(finance)
# /wiki/Option_style
# /wiki/Option_(finance)
# /wiki/Chicago_Board_Options_Exchange
# /wiki/Volatility_smile
# /wiki/Fischer_Black
# /wiki/Myron_Scholes
# /wiki/Journal_of_Political_Economy
# /wiki/Partial_differential_equation
# /wiki/Black%E2%80%93Scholes_equation
# /wiki/Hedge_(finance)
# /wiki/Delta_hedging
# /wiki/Investment_bank
# /wiki/Hedge_fund
# /wiki/Robert_C._Merton
# /wiki/Options_pricing
# /wiki/Nobel_Memorial_Prize_in_Economic_Sciences
# /wiki/Risk_management
# /wiki/Black-Scholes_formula
# /wiki/No-arbitrage_bounds
# /wiki/Risk-neutral_measure
# /wiki/Black-Scholes_equation
# /wiki/Volatility_surface
# /wiki/Derivative_(finance)#OTC_and_exchange-traded
# /wiki/Risk-free_interest_rate
# /wiki/Random_walk
# /wiki/Geometric_Brownian_motion
# /wiki/Dividend
# /wiki/Arbitrage
# /wiki/Short_selling
# /wiki/Frictionless_market
# /wiki/Hedge_(finance)
# /wiki/Transaction_cost
# /wiki/Strike_price
# /wiki/Risk-free_interest_rate
# /wiki/Continuous_compounding
# /wiki/Force_of_interest
# /wiki/Drift_rate
# /wiki/Quadratic_variation
# /wiki/Portfolio_(finance)
# /wiki/Standard_normal
# /wiki/Cumulative_distribution_function
# /wiki/Probability_density_function
# /wiki/Black%E2%80%93Scholes_equation
# /wiki/Partial_differential_equation
# /wiki/Hedge_(finance)
# /wiki/Underlying
# /wiki/Black%E2%80%93Scholes_model#Black.E2.80.93Scholes_formula
# /wiki/European_option
# /wiki/Put_option
# /wiki/Call_option
# /wiki/Consistency
# /wiki/Black%E2%80%93Scholes_model#The_Black.E2.80.93Scholes_equation_and_its_derivation
# /wiki/Equation_solving#Differential_equations
# /wiki/Put_option
# /wiki/Put%E2%80%93call_parity
# /wiki/Black%E2%80%93Scholes_model#Notation
# /wiki/Cumulative_distribution_function
# /wiki/Standard_normal_distribution
# /wiki/Spot_price
# /wiki/Risk_free_rate
# /wiki/Continuous_compounding
# /wiki/Volatility_(finance)
# /wiki/Black_model
# /wiki/Discount_factor
# /wiki/Forward_price
# /wiki/Binary_option
# /wiki/Asset-or-nothing_call
# /wiki/Cash-or-nothing_call
# /wiki/Moneyness
# /wiki/Num%C3%A9raire
# /wiki/Log-normal_distribution
# /wiki/It%C5%8D%27s_lemma#Geometric_Brownian_motion
# /wiki/Martingale_(probability_theory)
# /wiki/Num%C3%A9raire
# /wiki/Conditional_probability
# /wiki/Datar%E2%80%93Mathews_method_for_real_option_valuation#Interpretation
# /wiki/Datar%E2%80%93Mathews_method_for_real_option_valuation
# /wiki/Measure_(mathematics)
# /wiki/Market_price_of_risk
# /wiki/Martingale_pricing
# /wiki/Black-Scholes_equation
# /wiki/Feynman-Kac_formula
# /wiki/Martingale_(probability_theory)
# /wiki/Risk_neutrality
# /wiki/Expected_value
# /wiki/Probability_measure
# /wiki/Risk-neutral_measure
# /wiki/Rational_pricing#Risk_neutral_valuation
# /wiki/Rational_pricing
# /wiki/Mathematical_finance
# /wiki/Greeks_(finance)
# /wiki/Partial_derivatives
# /wiki/Closed-form_expression
# /wiki/Differentiation_(mathematics)
# /wiki/Put%E2%80%93call_parity
# /wiki/Option_style
# /wiki/Lattice_model_(finance)
# /wiki/Finite_difference_methods_for_option_pricing
# /wiki/Dividend_yield
# /wiki/American_option
# /wiki/Optimal_stopping
# /wiki/Quadratic_equation
# /wiki/Root_finding_algorithm
# /wiki/Barrier_option#Types
# /wiki/Put_call_parity
# /wiki/Stock_market_crash
# /wiki/Tail_risk
# /wiki/Out-of-the-money
# /wiki/Liquidity_risk
# /wiki/Volatility_risk
# /wiki/Delta_hedging
# /wiki/Log-normal_distribution
# /wiki/GARCH
# /wiki/Out-of-the-money
# /wiki/Greeks_(finance)
# /wiki/Stress_testing
# /wiki/Implied_volatility
# /wiki/Volatility_surface
# /wiki/Coordinate_transformation
# /wiki/Volatility_smile
# /wiki/Monotonic_function
# /wiki/Volatility_smile
# /wiki/At-the-money
# /wiki/At-the-money
# /wiki/Financial_economics#Challenges_and_criticism
# /wiki/Bond_(finance)
# /wiki/Pull_to_par
# /wiki/Black_model
# /wiki/Bond_option#Valuation
# /wiki/Yield_curve
# /wiki/Short_(finance)
# /wiki/Espen_Gaarder_Haug
# /wiki/Nassim_Nicholas_Taleb
# /wiki/Neoclassical_economics
# /wiki/Edward_O._Thorp
# /wiki/Emanuel_Derman
# /wiki/Paul_Wilmott
# /wiki/Ian_Stewart_(mathematician)
# /wiki/Berkshire_Hathaway
# /wiki/Warren_Buffett
# /wiki/Binomial_options_model
# /wiki/Numerical_method
# /wiki/Black_model
# /wiki/Black_Shoals
# /wiki/Brownian_model_of_financial_markets
# /wiki/Financial_mathematics
# /wiki/Heat_equation
# /wiki/Jump_diffusion
# /wiki/Monte_Carlo_option_model
# /wiki/Simulation
# /wiki/Real_options_analysis
# /wiki/Stochastic_volatility
# /wiki/Donald_Angus_MacKenzie
# /wiki/International_Standard_Book_Number
# /wiki/Zvi_Bodie
# /wiki/International_Standard_Book_Number
# /wiki/Digital_object_identifier
# /wiki/Digital_object_identifier
# /wiki/INSEAD
# /wiki/Prentice_Hall
# /wiki/International_Standard_Book_Number
# /wiki/Digital_object_identifier
# /wiki/Paul_Wilmott
# /wiki/Riccardo_Rebonato
# /wiki/International_Standard_Book_Number
# /wiki/Andrew_Kalotay
# /wiki/Espen_Gaarder_Haug
# /wiki/Nassim_Nicholas_Taleb
# /wiki/Emanuel_Derman
# /wiki/Nassim_Taleb
# /wiki/Boston_University
# /wiki/Ian_Stewart_(mathematician)
# /wiki/The_Observer
# /wiki/Digital_object_identifier
# /wiki/Digital_object_identifier
# /wiki/JSTOR
# /wiki/John_C._Hull
# /wiki/International_Standard_Book_Number
# /wiki/Peter_L._Bernstein
# /wiki/International_Standard_Book_Number
# /wiki/Digital_object_identifier
# /wiki/Digital_object_identifier
# /wiki/International_Standard_Book_Number
# /wiki/International_Standard_Book_Number
# /wiki/International_Standard_Book_Number
# /wiki/Ian_Stewart_(mathematician)
# /wiki/The_Observer
# /wiki/Emanuel_Derman
# /wiki/Terence_Tao
# /wiki/Midas_formula
# /wiki/Long-Term_Capital_Management
# /wiki/LTCM
# /wiki/Derivatives_market
# /wiki/Derivative_(finance)
# /wiki/Option_(finance)
# /wiki/Credit_spread_(options)
# /wiki/Debit_spread
# /wiki/Exercise_(options)
# /wiki/Expiration_(options)
# /wiki/Moneyness
# /wiki/Open_interest
# /wiki/Pin_risk_(options)
# /wiki/Risk-free_interest_rate
# /wiki/Strike_price
# /wiki/Greeks_(finance)
# /wiki/Volatility_(finance)
# /wiki/Vanilla_option
# /wiki/Bond_option
# /wiki/Call_option
# /wiki/Employee_stock_option
# /wiki/Fixed_income
# /wiki/Foreign-exchange_option
# /wiki/Option_style
# /wiki/Put_option
# /wiki/Warrant_(finance)
# /wiki/Exotic_option
# /wiki/Asian_option
# /wiki/Barrier_option
# /wiki/Basket_option
# /wiki/Binary_option
# /wiki/Chooser_option
# /wiki/Cliquet
# /wiki/Commodore_option
# /wiki/Compound_option
# /wiki/Forward_start_option
# /wiki/Interest_rate_option
# /wiki/Lookback_option
# /wiki/Mountain_range_(options)
# /wiki/Rainbow_option
# /wiki/Swaption
# /wiki/Options_strategies
# /wiki/Collar_(finance)
# /wiki/Fence_(finance)
# /wiki/Iron_butterfly_(options_strategy)
# /wiki/Iron_condor
# /wiki/Straddle
# /wiki/Strangle_(options)
# /wiki/Covered_call
# /wiki/Married_put
# /wiki/Risk_reversal
# /wiki/Options_spread
# /wiki/Backspread
# /wiki/Bear_spread
# /wiki/Box_spread
# /wiki/Bull_spread
# /wiki/Butterfly_(options)
# /wiki/Calendar_spread
# /wiki/Diagonal_spread
# /wiki/Intermarket_Spread
# /wiki/Ratio_spread
# /wiki/Vertical_spread
# /wiki/Valuation_of_options
# /wiki/Binomial_options_pricing_model
# /wiki/Black_model
# /wiki/Finite_difference_methods_for_option_pricing
# /wiki/Margrabe%27s_formula
# /wiki/Put%E2%80%93call_parity
# /wiki/Monte_Carlo_methods_for_option_pricing
# /wiki/Real_options_valuation
# /wiki/Trinomial_tree
# /wiki/Vanna%E2%80%93Volga_pricing
# /wiki/Swap_(finance)
# /wiki/Amortising_swap
# /wiki/Asset_swap
# /wiki/Basis_swap
# /wiki/Conditional_variance_swap
# /wiki/Constant_maturity_swap
# /wiki/Correlation_swap
# /wiki/Credit_default_swap
# /wiki/Currency_swap
# /wiki/Dividend_swap
# /wiki/Equity_swap
# /wiki/Foreign_exchange_swap
# /wiki/Inflation_swap
# /wiki/Interest_rate_swap
# /wiki/Overnight_indexed_swap
# /wiki/Total_return_swap
# /wiki/Variance_swap
# /wiki/Volatility_swap
# /wiki/Year-on-Year_Inflation-Indexed_Swap
# /wiki/Zero-Coupon_Inflation-Indexed_Swap
# /wiki/Forward_contract
# /wiki/Futures_contract
# /wiki/Contango
# /wiki/Currency_future
# /wiki/Dividend_future
# /wiki/Forward_market
# /wiki/Forward_price
# /wiki/Forward_contract#Spot.E2.80.93forward_parity
# /wiki/Forward_rate
# /wiki/Futures_contract#Pricing
# /wiki/Interest_rate_future
# /wiki/Margin_(finance)
# /wiki/Normal_backwardation
# /wiki/Single-stock_futures
# /wiki/Slippage_(finance)
# /wiki/Stock_market_index_future
# /wiki/Exotic_derivative
# /wiki/Energy_derivative
# /wiki/Freight_derivative
# /wiki/Inflation_derivative
# /wiki/Property_derivatives
# /wiki/Weather_derivative
# /wiki/Collateralized_debt_obligation
# /wiki/Constant_proportion_portfolio_insurance
# /wiki/Contract_for_difference
# /wiki/Credit-linked_note
# /wiki/Credit_default_option
# /wiki/Credit_derivative
# /wiki/Equity-linked_note
# /wiki/Equity_derivative
# /wiki/Foreign_exchange_derivative
# /wiki/Fund_derivative
# /wiki/Interest_rate_derivative
# /wiki/Mortgage-backed_security
# /wiki/Power_reverse_dual-currency_note
# /wiki/Consumer_debt
# /wiki/Corporate_bond
# /wiki/Government_debt
# /wiki/Great_Recession
# /wiki/Municipal_debt
# /wiki/Tax_policy
# /wiki/Hedge_fund
# /wiki/Arbitrage
# /wiki/Relative_value_(economics)
# /wiki/Capital_structure#Arbitrage
# /wiki/Convertible_arbitrage
# /wiki/Market_neutral#Equity-market-neutral
# /wiki/Fixed_income_arbitrage
# /wiki/Fixed-income_relative-value_investing
# /wiki/Statistical_arbitrage
# /wiki/Volatility_arbitrage
# /wiki/Event-driven_investing
# /wiki/Activist_shareholder
# /wiki/Distressed_securities
# /wiki/Risk_arbitrage
# /wiki/Special_situation
# /wiki/Convergence_trade
# /wiki/Commodity_trading_advisor
# /wiki/Managed_futures_account
# /wiki/Short_(finance)
# /wiki/Global_macro
# /wiki/Long/short_equity
# /wiki/Trend_following
# /wiki/Fund_of_funds#Fund_of_hedge_funds
# /wiki/Multi-manager_investment
# /wiki/Algorithmic_trading
# /wiki/Day_trading
# /wiki/High-frequency_trading
# /wiki/Prime_brokerage
# /wiki/Program_trading
# /wiki/Proprietary_trading
# /wiki/Commodity_market
# /wiki/Derivative_(finance)
# /wiki/Stock_market
# /wiki/Bond_market
# /wiki/Foreign_exchange_market
# /wiki/Money_market
# /wiki/Structured_finance
# /wiki/Arbitrage_pricing_theory
# /wiki/Assets_under_management
# /wiki/Greeks_(finance)
# /wiki/Delta_neutral
# /wiki/Capital_asset_pricing_model
# /wiki/Alpha_(investment)
# /wiki/Beta_(finance)
# /wiki/Security_characteristic_line
# /wiki/Fundamental_analysis
# /wiki/Hedge_(finance)
# /wiki/Securitization
# /wiki/Short_(finance)
# /wiki/Taxation_of_private_equity_and_hedge_funds
# /wiki/Technical_analysis
# /wiki/Vulture_fund
# /wiki/Family_office
# /wiki/Financial_endowment
# /wiki/Fund_of_funds#Fund_of_hedge_funds
# /wiki/High-net-worth_individual
# /wiki/Institutional_investor
# /wiki/Insurance#Insurance_companies
# /wiki/Investment_banking
# /wiki/Merchant_bank
# /wiki/Pension_fund
# /wiki/Sovereign_wealth_fund
# /wiki/Fund_governance
# /wiki/Stochastic_process
# /wiki/Discrete-time_stochastic_process
# /wiki/Bernoulli_process
# /wiki/Branching_process
# /wiki/Chinese_restaurant_process
# /wiki/Galton%E2%80%93Watson_process
# /wiki/Independent_and_identically_distributed_random_variables
# /wiki/Markov_chain
# /wiki/Moran_process
# /wiki/Random_walk
# /wiki/Loop-erased_random_walk
# /wiki/Self-avoiding_walk
# /wiki/Continuous-time_stochastic_process
# /wiki/Bessel_process
# /wiki/Birth%E2%80%93death_process
# /wiki/Wiener_process
# /wiki/Brownian_bridge
# /wiki/Brownian_excursion
# /wiki/Fractional_Brownian_motion
# /wiki/Geometric_Brownian_motion
# /wiki/Brownian_meander
# /wiki/Cauchy_process
# /wiki/Contact_process_(mathematics)
# /wiki/Continuous-time_random_walk
# /wiki/Cox_process
# /wiki/Diffusion_process
# /wiki/Empirical_process
# /wiki/Feller_process
# /wiki/Fleming%E2%80%93Viot_process
# /wiki/Gamma_process
# /wiki/Hunt_process
# /wiki/Interacting_particle_system
# /wiki/It%C3%B4_diffusion
# /wiki/It%C3%B4_process
# /wiki/Jump_diffusion
# /wiki/Jump_process
# /wiki/L%C3%A9vy_process
# /wiki/Local_time_(mathematics)
# /wiki/Markov_additive_process
# /wiki/McKean%E2%80%93Vlasov_process
# /wiki/Ornstein%E2%80%93Uhlenbeck_process
# /wiki/Poisson_process
# /wiki/Compound_Poisson_process
# /wiki/Non-homogeneous_Poisson_process
# /wiki/Poisson_point_process
# /wiki/Schramm%E2%80%93Loewner_evolution
# /wiki/Semimartingale
# /wiki/Sigma-martingale
# /wiki/Stable_process
# /wiki/Superprocess
# /wiki/Telegraph_process
# /wiki/Variance_gamma_process
# /wiki/Wiener_process
# /wiki/Wiener_sausage
# /wiki/Branching_process
# /wiki/Gaussian_process
# /wiki/Hidden_Markov_model
# /wiki/Markov_process
# /wiki/Martingale_(probability_theory)
# /wiki/Martingale_difference_sequence
# /wiki/Local_martingale
# /wiki/Submartingale
# /wiki/Supermartingale
# /wiki/Random_dynamical_system
# /wiki/Regenerative_process
# /wiki/Renewal_process
# /wiki/White_noise
# /wiki/Dirichlet_process
# /wiki/Gaussian_random_field
# /wiki/Gibbs_measure
# /wiki/Hopfield_model
# /wiki/Ising_model
# /wiki/Potts_model
# /wiki/Boolean_network
# /wiki/Markov_random_field
# /wiki/Percolation_theory
# /wiki/Pitman%E2%80%93Yor_process
# /wiki/Point_process
# /wiki/Point_process#Cox_point_process
# /wiki/Poisson_point_process
# /wiki/Random_field
# /wiki/Random_graph
# /wiki/Time_series
# /wiki/Autoregressive_conditional_heteroskedasticity
# /wiki/Autoregressive_integrated_moving_average
# /wiki/Autoregressive_model
# /wiki/Autoregressive%E2%80%93moving-average_model
# /wiki/GARCH
# /wiki/Moving-average_model
# /wiki/Black%E2%80%93Derman%E2%80%93Toy_model
# /wiki/Black%E2%80%93Karasinski_model
# /wiki/Chen_model
# /wiki/Constant_elasticity_of_variance_model
# /wiki/Cox%E2%80%93Ingersoll%E2%80%93Ross_model
# /wiki/Garman%E2%80%93Kohlhagen_model
# /wiki/Heath%E2%80%93Jarrow%E2%80%93Morton_framework
# /wiki/Heston_model
# /wiki/Ho%E2%80%93Lee_model
# /wiki/Hull%E2%80%93White_model
# /wiki/LIBOR_market_model
# /wiki/Rendleman%E2%80%93Bartter_model
# /wiki/SABR_volatility_model
# /wiki/Vasicek_model
# /wiki/Wilkie_investment_model
# /wiki/Actuarial_mathematics
# /wiki/B%C3%BChlmann_model
# /wiki/Cram%C3%A9r%E2%80%93Lundberg_model
# /wiki/Risk_process
# /wiki/Sparre%E2%80%93Anderson_model
# /wiki/Queueing_model
# /wiki/Bulk_queue
# /wiki/Fluid_queue
# /wiki/G-network
# /wiki/M/G/1_queue
# /wiki/M/M/1_queue
# /wiki/M/M/c_queue
# /wiki/C%C3%A0dl%C3%A0g
# /wiki/Continuous_stochastic_process
# /wiki/Sample-continuous_process
# /wiki/Ergodicity
# /wiki/Exchangeable_random_variables
# /wiki/Feller-continuous_process
# /wiki/Gauss%E2%80%93Markov_process
# /wiki/Markov_property
# /wiki/Mixing_(mathematics)
# /wiki/Piecewise_deterministic_Markov_process
# /wiki/Predictable_process
# /wiki/Progressively_measurable_process
# /wiki/Self-similar_process
# /wiki/Stationary_process
# /wiki/Time_reversibility
# /wiki/Central_limit_theorem
# /wiki/Donsker%27s_theorem
# /wiki/Doob%27s_martingale_convergence_theorems
# /wiki/Ergodic_theorem
# /wiki/Fisher%E2%80%93Tippett%E2%80%93Gnedenko_theorem
# /wiki/Large_deviation_principle
# /wiki/Law_of_large_numbers
# /wiki/Law_of_the_iterated_logarithm
# /wiki/Maximal_ergodic_theorem
# /wiki/Sanov%27s_theorem
# /wiki/List_of_inequalities#Probability_theory_and_statistics
# /wiki/Burkholder%E2%80%93Davis%E2%80%93Gundy_inequalities
# /wiki/Doob%27s_martingale_inequality
# /wiki/Kunita%E2%80%93Watanabe_inequality
# /wiki/Cameron%E2%80%93Martin_formula
# /wiki/Convergence_of_random_variables
# /wiki/Dol%C3%A9ans-Dade_exponential
# /wiki/Doob_decomposition_theorem
# /wiki/Doob%E2%80%93Meyer_decomposition_theorem
# /wiki/Doob%27s_optional_stopping_theorem
# /wiki/Dynkin%27s_formula
# /wiki/Feynman%E2%80%93Kac_formula
# /wiki/Filtration_(mathematics)#Measure_theory
# /wiki/Girsanov_theorem
# /wiki/Infinitesimal_generator_(stochastic_processes)
# /wiki/It%C3%B4_integral
# /wiki/It%C3%B4%27s_lemma
# /wiki/Kolmogorov_continuity_theorem
# /wiki/Kolmogorov_extension_theorem
# /wiki/L%C3%A9vy%E2%80%93Prokhorov_metric
# /wiki/Malliavin_calculus
# /wiki/Martingale_representation_theorem
# /wiki/Optional_stopping_theorem
# /wiki/Prohorov_theorem
# /wiki/Quadratic_variation
# /wiki/Reflection_principle_(Wiener_process)
# /wiki/Skorokhod_integral
# /wiki/Skorokhod%27s_representation_theorem
# /wiki/Skorokhod_space
# /wiki/Snell_envelope
# /wiki/Stochastic_differential_equation
# /wiki/Tanaka_equation
# /wiki/Stopping_time
# /wiki/Stratonovich_integral
# /wiki/Uniform_integrability
# /wiki/Usual_hypotheses
# /wiki/Wiener_space
# /wiki/Classical_Wiener_space
# /wiki/Abstract_Wiener_space
# /wiki/Actuarial_mathematics
# /wiki/Econometrics
# /wiki/Ergodic_theory
# /wiki/Extreme_value_theory
# /wiki/Large_deviations_theory
# /wiki/Mathematical_finance
# /wiki/Mathematical_statistics
# /wiki/Probability_theory
# /wiki/Queueing_theory
# /wiki/Renewal_theory
# /wiki/Ruin_theory
# /wiki/Statistics
# /wiki/Stochastic_analysis
# /wiki/Time_series_analysis
# /wiki/Machine_learning
# /wiki/List_of_stochastic_processes_topics

# %%
#TODO...
